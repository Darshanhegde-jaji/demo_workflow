# %%
from langgraph.graph import StateGraph, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import create_react_agent
from langchain_ollama import ChatOllama
from langchain_core.tools import tool
from pymongo import MongoClient
from typing_extensions import TypedDict, List, Union
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os
from typing import Annotated
from langgraph.graph.message import add_messages
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma
from langchain.chains import RetrievalQA
from langgraph.types import interrupt, Command
from youtube_transcript_api import YouTubeTranscriptApi
from langchain_tavily import TavilySearch
from langgraph.prebuilt import create_react_agent
from pymongo import MongoClient


load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")  

client = MongoClient("mongodb://localhost:27017/")
db = client["resume_db"]
users_col = db["users"]


class AppState(TypedDict):
    question: str
    answer: str
    search_results: str
    youtube_url: str
    video_transcript: str
    vector_store_path: str
    chatbot: RetrievalQA
    confidence: float
    messages:Annotated[List[dict], add_messages]

@tool(description="Searches the web using Tavily API. Input should be a search query.")
def travily_search(query: str) -> str:
    search = TavilySearch(max_results=5)
    return search.invoke(
        {query: query}
    )



llm = ChatOllama(model="llama3.1:8b", base_url="http://localhost:11434")
# llm2 =ChatGroq(
#     model="meta-llama/llama-4-scout-17b-16e-instruct"
# )

agent = create_react_agent(llm, tools=[travily_search])

def input_youtube_url(state: AppState) -> AppState:
    """Prompts the user to input a YouTube video URL."""
    youtube_url = interrupt("Enter the YouTube video id: ")
    state["youtube_url"] = youtube_url
    return state

def extract_youtube_transcript(state: AppState) -> AppState:
    """Extracts the transcript from a YouTube video URL."""
    loader =  YouTubeTranscriptApi()
    documents = loader.fetch(state["youtube_url"])
    full_transcript = " ".join([snippet.text for snippet in documents.snippets])
    state["video_transcript"] = full_transcript
    print(state["video_transcript"][:500])  # Print first 500 characters for debugging
    return state

def store_transcript_in_vector_db(state: AppState) -> AppState:
    """Stores the extracted transcript in a vector database."""
    persist_path = "./chroma_store/youtube_transcript" 

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
    chunks = text_splitter.split_text(state["video_transcript"])

    embeddings = OllamaEmbeddings(model="mxbai-embed-large", base_url="http://localhost:11434")
    vector_store = Chroma.from_texts(
        texts=chunks,
        embedding=embeddings,
        persist_directory=persist_path,
        collection_name="youtube_transcript_mxbai"
      )

    state["vector_store_path"] = persist_path
    # state["vector_store"] = vector_store 
    print(f"Stored {len(chunks)} chunks in vector database.")
    return state
    
def chatbot(state: AppState) -> AppState:
    """Creates a chatbot using the extracted transcript and vector database."""
    llm = ChatOllama(model="llama3.1:8b", base_url="http://localhost:11434")
    embeddings = OllamaEmbeddings(model="mxbai-embed-large", base_url="http://localhost:11434")
    vector_store = Chroma(
        persist_directory=state["vector_store_path"],
        embedding_function=embeddings,
        collection_name="youtube_transcript_mxbai"
    )
    question = state["question"]
    retrieved_docs = vector_store.similarity_search_with_score(question)
    # average_score = sum([s for _, s in retrieved_docs]) / len(retrieved_docs)
    # state["confidence"] =  average_score if average_score > 0 else 0
    
    chat_prompt = ChatPromptTemplate.from_messages([
        ("system", "You are a helpful assistant that answers questions based on the provided YouTube video transcript. Use the information from the transcript to answer the user's questions. If you don't know the answer, say 'I don't know'."),
        ("human", "Question: {question}\nContext: {context}\nAnswer:")
    ])
    
    answer_chain = chat_prompt | llm
    print("retrived_docs", retrieved_docs)
    ai_message = answer_chain.invoke({"question": question, "context": retrieved_docs})

    state["answer"] = ai_message.content if hasattr(ai_message, 'content') else str(ai_message)
    print(f"Answer: {state['answer']}")  
    return state

def ask_chatbot(state: AppState) -> AppState:
    """Allows the user to ask questions to the chatbot."""
    question = interrupt("Ask a question about the video (or type 'exit' to quit): ")
    if question and question.lower() != "exit":
        state["question"] = question
        return state
    else:
        return state

def create_agent(state: AppState) -> AppState:
    """Creates a React agent for the chatbot."""
    # search_result = agent.invoke(state["question"])
    messages = [{"role": "user", "content": state["question"]}]
    search_result = agent.invoke({"messages": messages})
    state["search_results"] = search_result
    return state

def get_confidence(state: AppState) -> float:
    """Returns the confidence score of the chatbot's answer."""
    llm = ChatOllama(model="llama3.1:8b", base_url="http://localhost:11434")
    embeddings = OllamaEmbeddings(model="llama3.1:8b", base_url="http://localhost:11434")
    vector_store = Chroma(
        persist_directory=state["vector_store_path"],
        embedding_function=embeddings,
        collection_name="youtube_transcript"
    )
    question = state["question"]
    retrieved_docs = vector_store.similarity_search_with_score(question)
    average_score = sum([s for _, s in retrieved_docs]) / len(retrieved_docs)
    state["confidence"] = 1 - average_score if average_score > 0 else 0
    return state.get("confidence", 0.0)

def should_continue(state: AppState) -> str:
    """Determines whether to continue asking questions or end."""
    if "question" not in state or state.get("question", "").lower() == "exit":
        return "end"
    return "continue"

builder = StateGraph(AppState)

builder.add_node("input_youtube_url", input_youtube_url)
builder.add_node("extract_youtube_transcript", extract_youtube_transcript)
builder.add_node("store_transcript_in_vector_db", store_transcript_in_vector_db)
builder.add_node("chatbot", chatbot)
builder.add_node("ask_chatbot", ask_chatbot)
builder.add_node("agent", create_agent)

builder.set_entry_point("input_youtube_url")
builder.add_edge("input_youtube_url", "extract_youtube_transcript")
builder.add_edge("extract_youtube_transcript", "store_transcript_in_vector_db")
builder.add_edge("store_transcript_in_vector_db", "ask_chatbot")
# builder.add_edge("ask_chatbot", "chatbot")
builder.add_conditional_edges(
    "ask_chatbot",
    should_continue,
    {
        "continue": "chatbot",
        "end": END
    }
)
builder.add_edge("chatbot", "ask_chatbot")


# config = {"configurable": {"thread_id": "1"}}
# # checkpointer = InMemorySaver()
# client = MongoClient("mongodb://localhost:23017")
# mongo_checkpointer = MongoDBSaver(client=client,
#                                   db_name="langgraph_memory",
#                                   collection_name="checkpoints")
# graph = builder.compile(checkpointer=mongo_checkpointer)

# result = graph.invoke({}, config=config)

# %%
user_input = input("Enter the YouTube video id: ")
graph.invoke(Command(resume=user_input), config=config)
# Out:
# retrived_docs [(Document(id='88090c9b-a17d-4518-b410-8df975ebf955', metadata={}, page_content="Now, the fallout from Israel's strike targeting Hamas leaders in Doha is set to dominate two high-profile meetings in the Middle East today. In Doha, Arab and Muslim leaders are gathering for an emergency summit to coordinate their response and call for the international community to punish Israel. While the Qatari prime minister called the Israeli attack state terrorism, but also said his country remained committed to trying to reach a ceasefire to end the nearly 2-year long war that has devastated Gaza. Israel has defended the strike on Qatari soil. Iran's president is amongst those leaders attending the meeting. We've seen Massud Pescan departing from Thran. He's urging Muslim countries to cut ties with Israel ahead of the summit. In Israel, the Prime Minister Benjamin Netanyahu is meeting with the US Secretary of State Marco Rubio for a second day. Their bilateral has just got underway. Mr. Netanyahu hailed the visit as a sign that the USIsrael alliance is stronger than it's ever"), 0.7259079813957214), (Document(id='56b4fd34-fc60-4ae6-a254-ce0b91ad05c2', metadata={}, page_content="Now, the fallout from Israel's strike targeting Hamas leaders in Doha is set to dominate two high-profile meetings in the Middle East today. In Doha, Arab and Muslim leaders are gathering for an emergency summit to coordinate their response and call for the international community to punish Israel. While the Qatari prime minister called the Israeli attack state terrorism, but also said his country remained committed to trying to reach a ceasefire to end the nearly 2-year long war that has devastated Gaza. Israel has defended the strike on Qatari soil. Iran's president is amongst those leaders attending the meeting. We've seen Massud Pescan departing from Thran. He's urging Muslim countries to cut ties with Israel ahead of the summit. In Israel, the Prime Minister Benjamin Netanyahu is meeting with the US Secretary of State Marco Rubio for a second day. Their bilateral has just got underway. Mr. Netanyahu hailed the visit as a sign that the USIsrael alliance is stronger than it's ever"), 0.7259079813957214), (Document(id='2707c01a-8ac7-4bd4-80bf-c11c765a3289', metadata={}, page_content="whilst you were talking, we're just bringing up these live shots we're getting from Gaza showing people um fleeing, we're told, from the northern Gaza Strip and Gaza City to southern Gaza. Just tell us what we know about what's going on on the ground there. Yeah, there almost apeltic scenes uh in Gaza now. The Israelis themselves say that 300,000 people have left Gaza City, a city where about a million people are thought to be either living or sheltering. Israeli air strikes have continued over the weekend. Many more high-rise buildings destroyed which Israel says are being used by Hamas. uh but uh many in the international community and particularly those under Garen's side say it's it's an exercise in a scorched earth policy. Israel is also preparing for a ground offensive because Netanyahu has made it clear he wants to uh defeat Hamas in Gaza city and the rest of the Gaza Strip before he is ready to end the war. So a lot of concerns on humanitarian front. Israel says it will"), 0.823818564414978), (Document(id='6b993b1a-b560-4cb5-a028-0f03452e2ae1', metadata={}, page_content="whilst you were talking, we're just bringing up these live shots we're getting from Gaza showing people um fleeing, we're told, from the northern Gaza Strip and Gaza City to southern Gaza. Just tell us what we know about what's going on on the ground there. Yeah, there almost apeltic scenes uh in Gaza now. The Israelis themselves say that 300,000 people have left Gaza City, a city where about a million people are thought to be either living or sheltering. Israeli air strikes have continued over the weekend. Many more high-rise buildings destroyed which Israel says are being used by Hamas. uh but  ...
# Answer: According to the transcript, the target of Israel's strike was Hamas leaders in Doha.
# {'question': "Israel's strike targeting whom?",
#  'answer': "According to the transcript, the target of Israel's strike was Hamas leaders in Doha.",
#  'youtube_url': 'zxclFPA9mqY',
#  'video_transcript': "Now, the fallout from Israel's strike targeting Hamas leaders in Doha is set to dominate two high-profile meetings in the Middle East today. In Doha, Arab and Muslim leaders are gathering for an emergency summit to coordinate their response and call for the international community to punish Israel. While the Qatari prime minister called the Israeli attack state terrorism, but also said his country remained committed to trying to reach a ceasefire to end the nearly 2-year long war that has devastated Gaza. Israel has defended the strike on Qatari soil. Iran's president is amongst those leaders attending the meeting. We've seen Massud Pescan departing from Thran. He's urging Muslim countries to cut ties with Israel ahead of the summit. In Israel, the Prime Minister Benjamin Netanyahu is meeting with the US Secretary of State Marco Rubio for a second day. Their bilateral has just got underway. Mr. Netanyahu hailed the visit as a sign that the USIsrael alliance is stronger than it's ever been. Asked by reporters in Washington what his message to the Israeli prime minister would be after Israeli jets bombed Doha last week, here's what the US president had to say. >> They have to be very, very careful. They have to do something about Hamas. But Qatar has been Qatar has been a very great ally. So Israel and everybody else, we have to be careful when when we attack people. We have to be careful. >> Well, joining me now, a correspondent in Jerusalem, Mura Davis and Nafisa Konavad, who's in Doha. Thanks very much both. Um, Nafisa, to you first. Just tell us what um the organizers of this summit are hoping to gain from it. This summit was organized at the request of Qatar and it's kind of show of solidarity in the region and across Islamic countries and Islamic Arabic and some other Islamic countries like Iran. Solidarity with uh Qatar that was attacked by Israel. Israel says that the attack wasn't against Qatar itself but here atmosphere in Doha is that they considered an attack for killing Hamas leaders against uh this country's sovereignty. So it was very important for Qatar to show that regional countries also will come to support um Qatar against any further threat which continue. um Israeli prime minister um repeatedly has said that wherever they want and if they see any threat against them, they are going to pursue and um repeat such attack against any countries including Kata if they still uh host um Hamas leaders. So in this way it is significant but um lines of resolution that is um expected that it will be the ending resolution of this summit signed by uh leaders that are here now in DHA. um it's leaking to the media and it shows that it's kind of is not going further than a political diplomatic condemnation although there is a warning against Israel that such attack and such acts can jeopardize any normalization with any countries in the region and also jeopardize Israel's relationships with um other countries in the region. ion that they just started to normalize their relationship with with Israel and we're Davis in Jerusalem. We've got this visit from the Secretary of State Marco Rubio, the Secretary of State um to Israel. Um, of course, we have also had these comments from Donald Trump as it balances its relations with two allies. Yeah. Look, there are very public uh shows of unity between Benjamin Netanyahu and Marco Rubio yesterday at the Western Wall and there will be opportunities across Jerusalem today for them to repeat those scenes, but you're quite right behind the scenes. It's been a very difficult week for for Israel and the Americans. We understand there was a a pretty tense phone call between Donald Trump and Benjamin Netanyahu last week in which Mr. Trump reportedly berated Mr. Netanyahu for that Israeli attack on Hamas leaders in Qatar which happened apparently without warning the Americans beforehand and we've heard um the Americans say several times publicly that they didn't agree wit ...
#  'vector_store_path': './chroma_store/youtube_transcript',
#  'messages': [],
#  '__interrupt__': [Interrupt(value="Ask a question about the video (or type 'exit' to quit): ", id='f4feea5561faec8b07fa4c79e00484a4')]}
